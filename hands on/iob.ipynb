# %%
import pandas as pd
import matplotlib.pyplot as plt 
import pylab as pt
import numpy as np
import seaborn as sbn
from sklearn import model_selection as ms
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("IOB (20240207000000000 _ 20210630000000000).csv")
df.describe()
# Out:
#              Open        High         Low       Close    % Change  \
# count  648.000000  648.000000  648.000000  648.000000  648.000000
# mean    25.528549   26.122531   25.014429   25.499691    0.214275
# std      8.844313    9.317028    8.615878    9.001368    3.107035
# min     15.400000   16.000000   15.250000   15.350000  -14.660000
# 25%     18.987500   19.287500   18.687500   18.950000   -1.380000
# 50%     22.850000   23.300000   22.175000   22.725000   -0.210000
# 75%     27.200000   28.187500   26.500000   27.162500    1.072500
# max     68.050000   79.850000   68.000000   76.200000   19.080000
#
#        % Change vs Average
# count           648.000000
# mean              0.000077
# std               3.106951
# min             -14.870000
# 25%              -1.592500
# 50%              -0.420000
# 75%               0.852500
# max              18.870000

# %%
df.info()
df.size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 648 non-null    object
#  1   Open                 648 non-null    float64
#  2   High                 648 non-null    float64
#  3   Low                  648 non-null    float64
#  4   Close                648 non-null    float64
#  5   % Change             648 non-null    float64
#  6   % Change vs Average  648 non-null    float64
#  7   Volume               648 non-null    object
# dtypes: float64(6), object(2)
# memory usage: 40.6+ KB
# 5184

# %%
df.head()
# Out:
#                                                 Date   Open   High    Low  \
# 0  Wed Jun 30 2021 00:00:00 GMT+0530 (India Stand...  26.00  29.00  26.00
# 1  Thu Jul 01 2021 00:00:00 GMT+0530 (India Stand...  28.35  28.95  27.20
# 2  Fri Jul 02 2021 00:00:00 GMT+0530 (India Stand...  27.45  28.40  27.10
# 3  Mon Jul 05 2021 00:00:00 GMT+0530 (India Stand...  27.80  28.10  26.90
# 4  Tue Jul 06 2021 00:00:00 GMT+0530 (India Stand...  27.20  27.35  26.05
#
#    Close  % Change  % Change vs Average      Volume
# 0  28.05      8.72                 8.51  89,616,855
# 1  27.35     -2.50                -2.71  44,266,806
# 2  27.45      0.37                 0.15  22,978,061
# 3  27.15     -1.09                -1.31  20,969,983
# 4  26.20     -3.50                -3.71  17,531,183

# %%
df.isnull().sum()
# Out:
# Date                   0
# Open                   0
# High                   0
# Low                    0
# Close                  0
# % Change               0
# % Change vs Average    0
# Volume                 0
# dtype: int64

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
np.random.seed(42)
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(df,test_size=0.2,random_state=42)

# %%
test_set.head()
test_set.size
# Out:
# 1040

# %%
df['Open'].hist()
# Out:
# <Axes: >

# %%
linear_reg=LinearRegression()
# Out:
# 0    26.00
# 1    28.35
# 2    27.45
# 3    27.80
# 4    27.20
# Name: Open, dtype: float64
# <Axes: ylabel='Open'>

# %%
sbn.histplot(x=firstFive['Date'],y=firstFive['Open'])
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date', ylabel='Open'>
